# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_test = pd.read_csv('titanic/test.csv')
df_train = pd.read_csv('titanic/train.csv')
df_gender = pd.read_csv('titanic/gender_submission.csv')

# %%
df_test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_gender.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0

# %%
df_test = df_test.dropna(subset=["Cabin", "Sex", "Pclass"])

# %%
df_test.head(10)
# Out:
#     PassengerId  Pclass                                               Name  \
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26          918       1                       Ostby, Miss. Helene Ragnhild
# 28          920       1                            Brady, Mr. John Bertram
# 34          926       1                           Mock, Mr. Philipp Edmund
# 41          933       1                        Franklin, Mr. Thomas Parham
# 44          936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46          938       1                           Chevre, Mr. Paul Romaine
# 48          940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
#
#        Sex   Age  SibSp  Parch       Ticket      Fare            Cabin  \
# ...

# %%
df_train = df_train.dropna(subset=["Cabin", "Sex", "Pclass"])

# %%
df_train.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# ...

# %%
df_all = pd.merge(df_test, df_gender, on="PassengerId")
df_all.head(10)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 1          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 2          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 3          918       1                       Ostby, Miss. Helene Ragnhild
# 4          920       1                            Brady, Mr. John Bertram
# 5          926       1                           Mock, Mr. Philipp Edmund
# 6          933       1                        Franklin, Mr. Thomas Parham
# 7          936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 8          938       1                           Chevre, Mr. Paul Romaine
# 9          940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
#
#       Sex   Age  SibSp  Parch       Ticket      Fare            Cabin  \
# 0  female  23.0      1      0        21228   82.2667              B45
# ...

# %%
df_all.sort_values('Fare', ascending=False)
# Out:
#     PassengerId  Pclass                                               Name  \
# 72         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 16          961       1                Fortune, Mrs. Mark (Mary McDougald)
# 11          945       1                         Fortune, Miss. Ethel Flora
# 13          951       1                        Chaudanson, Miss. Victorine
# 14          956       1                        Ryerson, Master. John Borie
# ..          ...     ...                                                ...
# 49         1114       2                         Cook, Mrs. (Selena Rogers)
# 12          949       3                      Abelseth, Mr. Olaus Jorgensen
# 59         1180       3                            Mardirosian, Mr. Sarkis
# 67         1213       3                              Krekorian, Mr. Neshan
# 78         1264       1                            Ismay, Mr. Joseph Bruce
#
# ...

# %%
survival_rates = df_all.groupby(["Sex", "Pclass"])["Survived"].mean().reset_index()
print(survival_rates)
# Out:
#       Sex  Pclass  Survived
# 0  female       1       1.0
# 1  female       2       1.0
# 2  female       3       1.0
# 3    male       1       0.0
# 4    male       2       0.0
# 5    male       3       0.0

# %%
df_all["Survived"] = pd.to_numeric(df_all["Survived"], errors="coerce")
survival_rates = df_all.groupby(["Sex", "Pclass"])["Survived"].mean().reset_index()
print(survival_rates)
# Out:
#       Sex  Pclass  Survived
# 0  female       1       1.0
# 1  female       2       1.0
# 2  female       3       1.0
# 3    male       1       0.0
# 4    male       2       0.0
# 5    male       3       0.0

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Sex", y="Survived", data=df_all, estimator=lambda x: sum(x)/len(x))
plt.title("Survival Rate by Gender")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Pclass", y="Survived", data=df_all, estimator=lambda x: sum(x)/len(x))
plt.title("Survival Rate by Passenger Class")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="Pclass", y="Survived", hue="Sex", data=df_all, estimator=lambda x: sum(x)/len(x))
plt.title("Survival Rate by Gender and Class")
plt.show()
